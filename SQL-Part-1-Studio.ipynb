-- %% [markdown]
-- # SQL Part 1 Studio
--
-- ### Let's practice your SQL quering skills!  For each question, work along in the notebook adding your query and answering the questions.
--
-- ### **DataSet**
--
-- ### <span style="font-size: 14px; font-family: -apple-system, BlinkMacSystemFont, sans-serif;">We will be using the Goodbooks-10k dataset from the exercises in the prep work.&nbsp; Feel free to reference your notebook.</span>
--
-- - The dataset can be found here: [goodbooks-10k](https://www.kaggle.com/zygmunt/goodbooks-10k)
-- - You can access the **BooksDB** in the Launchcode server.
--
-- ### **Business Issue**
--
-- You work for a small independant book store and you want to increase sales by running various promotions.  Start by becoming more familar with the BooksDB.

-- %% [markdown]
-- ## Part 1. Books Table
--
-- <span style="color: rgba(0, 0, 0, 0.87); font-family: -apple-system, system-ui, &quot;Segoe UI&quot;, Helvetica, Arial, sans-serif, &quot;Apple Color Emoji&quot;, &quot;Segoe UI Emoji&quot;, &quot;Segoe UI Symbol&quot;; background-color: rgb(255, 255, 255);">Question 1:&nbsp; Write a SELECT statement that queries the books table, returning the TOP 100 results and&nbsp; includes book_id, authors, title, average_rating.&nbsp; Use an alias for at least one column and in descending order of rating.&nbsp; What is the number one book?</span>

-- %%
-- return top 100 results

-- %% [markdown]
-- Question 2: Write a query to find the least popular book

-- %%
-- return least popular book

-- %% [markdown]
-- Question #: Which tag is the most popular?

-- %%
-- return most popular tag

-- %% [markdown]
-- Question #: What is the name of the most popular tag?

-- %%
-- return name of most popular tag

-- %% [markdown]
-- How many books where released in the first decade of 2000?

-- %%
-- return number of book published in the first decade of 2000

-- %% [markdown]
-- Question #: Create a querry that return how many titles books constain the word Happy?

-- %%
-- return number of books that contain the word Happy

-- %% [markdown]
-- Question 4: List the All the books from the top 3 authors from question 1.  If there is more than one author just use the first one. Sort the titles <span style="background-color: rgba(127, 127, 127, 0.1); font-family: -apple-system, BlinkMacSystemFont, sans-serif;">alphabetically by author and then by average_rating, best rated to lowest. Does order matter in sorting?</span>

-- %%
-- return all books from the top 3 authors, sort by author and rating

-- %% [markdown]
-- Question 5: Take a close look at J.K. Rowling.  Is her top rated book on this list from question 1?  Why might this be? How could we account for this?
--
-- Answer - It is not.  The reason is that under aurthors, each instance where the contents vary creates a separate but distinct author, we could use a %(wild card) to search each distinct author cell and include if any part has her name.

-- %% [markdown]
-- Try updating your above querry to include all of JK Rowlings books.
--
-- Are there any other issues?
--
-- Answer - Yes we are unable to group JK Rowlings works together to get a sort from best to least liked(rating)

-- %%
-- Try updating your above querry to include all of JK Rowlings books.

-- %% [markdown]
-- Question 6: Write a query that return the number of Authors whose first name is between rock and roll.

-- %%
-- return number of authors whose first name is between rock and roll

-- %% [markdown]
-- # Part 2. Write your own question and write a query to answer it.
--
-- Your Question:  Click here to add

-- %%
-- Add your querry here

-- %% [markdown]
-- Your Question: Click here to add

-- %%
-- Add your querry here

-- %% [markdown]
-- **Some Question Examples:**
--
-- Write a query that returns the longest title?
--
-- Which Author has written the most books?
--
-- Top  ten books written the year I was born?
